# %% [markdown]
# Para repasar distintos comandos

# %%
import pandas as pd
import numpy as nd

# %%
# Apertura de dataset

ds=pd.read_csv("/workspaces/Stress_detection/data/stress_detection_data.csv")
ds.head()

#muestra columnas
ds.columns
# Out:
# Index(['Age', 'Gender', 'Occupation', 'Marital_Status', 'Sleep_Duration',
#        'Sleep_Quality', 'Wake_Up_Time', 'Bed_Time', 'Physical_Activity',
#        'Screen_Time', 'Caffeine_Intake', 'Alcohol_Intake', 'Smoking_Habit',
#        'Work_Hours', 'Travel_Time', 'Social_Interactions',
#        'Meditation_Practice', 'Exercise_Type', 'Blood_Pressure',
#        'Cholesterol_Level', 'Blood_Sugar_Level', 'Stress_Detection'],
#       dtype='object')

# %%
# Ver algunas filas

ds.iloc[[0,1,4]]  #muestra filas seleccionadas
ds.iloc[2:4]   # rango de filas

#Ver algunas columnas
ds[["Age","Gender"]]

#Eliminar columna
ds.drop(["Age","Gender"],axis=1)

#Eliminar filas
ds.drop([0,3])
# Out:
# Index(['Age', 'Gender', 'Occupation', 'Marital_Status', 'Sleep_Duration',
#        'Sleep_Quality', 'Wake_Up_Time', 'Bed_Time', 'Physical_Activity',
#        'Screen_Time', 'Caffeine_Intake', 'Alcohol_Intake', 'Smoking_Habit',
#        'Work_Hours', 'Travel_Time', 'Social_Interactions',
#        'Meditation_Practice', 'Exercise_Type', 'Blood_Pressure',
#        'Cholesterol_Level', 'Blood_Sugar_Level', 'Stress_Detection'],
#       dtype='object')

# %%
# Ver group by y merge

# %%
# Análisis de valores nulos
ds.isnull().sum().sort_values(ascending=False)

#Eliminación de valores nulos
ds.dropna()
ds
# Out:
#      Age  Gender         Occupation Marital_Status  Sleep_Duration  \
# 0     30    Male  Software Engineer         Single             7.0
# 1     35  Female  Marketing Manager        Married             6.0
# 2     40    Male     Data Scientist       Divorced             7.0
# 3     35    Male  Software Engineer         Single             7.0
# 4     29  Female            Teacher         Single             8.0
# ..   ...     ...                ...            ...             ...
# 768   40  Female            Teacher         Single             6.3
# 769   42    Male             Writer        Married             6.0
# 770   30  Female         Accountant         Single             6.1
# 771   34    Male          Architect        Married             6.2
# 772   29  Female          Scientist         Single             6.3
#
#      Sleep_Quality Wake_Up_Time  Bed_Time  Physical_Activity  Screen_Time  \
# 0              4.0      7:00 AM  10:00 PM                2.0          4.0
# ...

# %%
# Variables numéricas y categóricas:

numerical_columns = ds.select_dtypes(include=['number']).columns
categorical_columns = ds.select_dtypes(include=['object']).columns

ds[categorical_columns]

#Describe las medidas estadísticas de las variables numéricas

ds.describe()
